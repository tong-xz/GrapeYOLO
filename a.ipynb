# %%
from ultralytics import YOLO
import time
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from tools.ObjectDetector import Detector
# Out:
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at 'C:\Users\txz20\AppData\Roaming\Ultralytics\settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'.

# %%
image_path = '13A.jpg'
detector = Detector('./results/detect/train25/weights/best.pt')
result = detector.inference(image_path)
box_dict = detector.get_all_boxes(result)
# Out:
# 0: 640x480 1 grape_cluster, 1 index, 1 measure_label, 132.2ms
# Speed: 7.0ms preprocess, 132.2ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 480)

# %%
detector.plt_all_boxes(image_path, box_dict)

# %%
from tools.Segmentator import Segmentator
import numpy as np
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from tools.Segmentator import Segmentator
#       2 import numpy as np
#       3 import torch
#
# File E:\Dev\GrapeYOLO\tools\Segmentator.py:4
#       1 # import os
#       2 # os.chdir('../FastSAM')
# ----> 4 from FastSAM.fastsam import FastSAM, FastSAMPrompt
#       5 import torch
#       6 import numpy as np
#
# File E:\Dev\GrapeYOLO\FastSAM\fastsam\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .model import FastSAM
#       4 from .predict import FastSAMPredictor
#       5 from .prompt import FastSAMPrompt
#
# File E:\Dev\GrapeYOLO\FastSAM\fastsam\model.py:12
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       2 """
#       3 FastSAM model interface.
#       4
#    (...)
#       9     results = model.predict('ultralytics/assets/bus.jpg')
#      10 """
# ---> 12 from ultralytics.yolo.cfg import get_cfg
#      13 from ultralytics.yolo.engine.exporter import Exporter
#      14 from ultralytics.yolo.engine.model import YOLO
#
# ModuleNotFoundError: No module named 'ultralytics.yolo'

# %%
import cv2

image = cv2.imread('13A.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
box_dict['grape_cluster']
